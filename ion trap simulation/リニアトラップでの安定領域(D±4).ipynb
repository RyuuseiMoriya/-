# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

#--リニアトラップ(D±4までの近似・Be+のみ)--

#--Be+--

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistBe0 = []
q_xlistBe0 = []

def f(a_x, q_x, beta_x):#関数を定義
    
     S_1 = (a_x - (2 + beta_x)**2)*(a_x - (4 + beta_x)**2) - q_x**2#D_4の分母
     S_2 = (a_x - (-2 + beta_x)**2)*(a_x - (-4 + beta_x)**2) - q_x**2#D_-4の分母
     S = (a_x - (4 + beta_x)**2)/ S_1 + (a_x - (-4 + beta_x)**2)/ S_2#連分数
     return  beta_x**2 - a_x + q_x**2 * S#方程式

a_guess = 0.0#初期値

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe0.append(a_x)
 q_xlistBe0.append(q_x)

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistBe1 = []
q_xlistBe1 = []

a_guess = 0.0#初期値

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe1.append(a_x)
 q_xlistBe1.append(q_x)

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistBe0 = []
q_ylistBe0 = []
a_xlistBe01 = []
q_xlistBe01 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe0.append(a_y)
 q_ylistBe0.append(q_y)
 a_xlistBe01.append(-a_y)#a_xに変換(a_x = -a_y)
 q_xlistBe01.append(-q_y)#q_xに変換(q_x = -q_y)

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistBe1 = []
q_ylistBe1 = []
a_xlistBe11 = []
q_xlistBe11 = []

a_guess = 0.0#初期値

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe1.append(a_y)
 q_ylistBe1.append(q_y)
 a_xlistBe11.append(-a_y)#a_xに変換(a_x = -a_y)
 q_xlistBe11.append(-q_y)#q_xに変換(q_x = -q_y)


 a_guess = a_y

plt.figure(figsize=(10,6))
plt.plot(q_xlistBe0, a_xlistBe0, color='blue', label=r'$Be^+ (\beta_x = 0)$', linewidth = 2)#β_xの下限
plt.plot(q_xlistBe1, a_xlistBe1, color='red', label=r'$Be^+ (\beta_x = 1)$', linewidth = 2)#β_xの上限
plt.plot(q_xlistBe01, a_xlistBe01, color='green', label=r'$Be^+ (\beta_y = 0)$', linewidth = 2)#β_yの下限
plt.plot(q_xlistBe11, a_xlistBe11, color='orange', label=r'$Be^+ (\beta_y = 1)$', linewidth = 2)#β_yの上限
plt.xlabel(r'$q_x$')
plt.ylabel(r'$a_x$')
plt.title('Stability diagram at D±4 in a linear trap')
plt.grid(True)
plt.xlim(0, 1)
plt.ylim(-0.4, 0.4)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

#--リニアトラップ(D±4までの近似)--
#--Be+のa, qを軸に取り、Be2+, He+, He2+, Ca+, Ca2+をプロットした-- 

#--Be+--

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistBe0 = []
q_xlistBe0 = []

def f(a_x, q_x, beta_x):#関数を定義
    
     S_1 = (a_x - (2 + beta_x)**2)*(a_x - (4 + beta_x)**2) - q_x**2#D_4の分母
     S_2 = (a_x - (-2 + beta_x)**2)*(a_x - (-4 + beta_x)**2) - q_x**2#D_-4の分母
     S = (a_x - (4 + beta_x)**2)/ S_1 + (a_x - (-4 + beta_x)**2)/ S_2#連分数
     return  beta_x**2 - a_x + q_x**2 * S#方程式

a_guess = 0.0#初期値

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe0.append(a_x)
 q_xlistBe0.append(q_x)

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistBe1 = []
q_xlistBe1 = []

a_guess = 0.0#
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe1.append(a_x)
 q_xlistBe1.append(q_x)

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistBe0 = []
q_ylistBe0 = []
a_xlistBe01 = []
q_xlistBe01 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe0.append(a_y)
 q_ylistBe0.append(q_y)
 a_xlistBe01.append(-a_y)#a_xに変換
 q_xlistBe01.append(-q_y)#q_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistBe1 = []
q_ylistBe1 = []
a_xlistBe11 = []
q_xlistBe11 = []

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe1.append(a_y)
 q_ylistBe1.append(q_y)
 a_xlistBe11.append(-a_y)#a_xに変換
 q_xlistBe11.append(-q_y)#q_xに変換

 a_guess = a_y



#---Be2+---

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistBe2 = []
q_xlistBe2 = []


a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe2.append(2*a_x)#Be+のa_xに変換
 q_xlistBe2.append(2*q_x)#Be+のq_xに変換

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistBe21 = []
q_xlistBe21 = []

a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe21.append(2*a_x)#Be+のa_xに変換
 q_xlistBe21.append(2*q_x)#Be+のq_xに変換

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistBe2 = []
q_ylistBe2 = []
a_xlistBe201 = []
q_xlistBe201 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe2.append(a_y)
 q_ylistBe2.append(q_y)
 a_xlistBe201.append(-2*a_y)#Be+のa_xに変換
 q_xlistBe201.append(-2*q_y)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistBe21 = []
q_ylistBe21 = []
a_xlistBe211 = []
q_xlistBe211 = []

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe21.append(a_y)
 q_ylistBe21.append(q_y)
 a_xlistBe211.append(-2*a_y)#Be+のa_xに変換
 q_xlistBe211.append(-2*q_y)#Be+のq_xに変換

 a_guess = a_y




#---He+---

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistHe0 = []
q_xlistHe0 = []


a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistHe0.append(9 * a_x / 4)#Be+のa_xに変換
 q_xlistHe0.append(9 * q_x / 4)#Be+のq_xに変換

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistHe1 = []
q_xlistHe1 = []

a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistHe1.append(9 * a_x / 4)#Be+のa_xに変換
 q_xlistHe1.append(9 * q_x / 4)#Be+のq_xに変換

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistHe0 = []
q_ylistHe0 = []
a_xlistHe01 = []
q_xlistHe01 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistHe0.append(a_y)
 q_ylistHe0.append(q_y)
 a_xlistHe01.append(-9 * a_y / 4)#Be+のa_xに変換
 q_xlistHe01.append(-9 * q_y / 4)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistHe1 = []
q_ylistHe1 = []
a_xlistHe11 = []
q_xlistHe11 = []

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistHe1.append(a_y)
 q_ylistHe1.append(q_y)
 a_xlistHe11.append(-9 * a_y / 4)#Be+のa_xに変換
 q_xlistHe11.append(-9 * q_y / 4)#Be+のq_xに変換

 a_guess = a_y


#---He2+---

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistHe20 = []
q_xlistHe20 = []


a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistHe20.append(9 * a_x / 2)#Be+のa_xに変換
 q_xlistHe20.append(9 * q_x / 2)#Be+のq_xに変換

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistHe21 = []
q_xlistHe21 = []

a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistHe21.append(9 * a_x / 2)#Be+のa_xに変換
 q_xlistHe21.append(9 * q_x / 2)#Be+のq_xに変換

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistHe20 = []
q_ylistHe20 = []
a_xlistHe201 = []
q_xlistHe201 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistHe20.append(a_y)
 q_ylistHe20.append(q_y)
 a_xlistHe201.append(-9 * a_y / 2)#Be+のa_xに変換
 q_xlistHe201.append(-9 * q_y / 2)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistHe21 = []
q_ylistHe21 = []
a_xlistHe211 = []
q_xlistHe211 = []

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistHe21.append(a_y)
 q_ylistHe21.append(q_y)
 a_xlistHe211.append(-9 * a_y / 2)#Be+のa_xに変換
 q_xlistHe211.append(-9 * q_y / 2)#Be+のq_xに変換

 a_guess = a_y


#---Ca+---

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistCa0 = []
q_xlistCa0 = []


a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistCa0.append(9 * a_x / 43)#Be+のa_xに変換
 q_xlistCa0.append(9 * q_x / 43)#Be+のq_xに変換

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistCa1 = []
q_xlistCa1 = []

a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistCa1.append(9 * a_x / 43)#Be+のa_xに変換
 q_xlistCa1.append(9 * q_x / 43)#Be+のq_xに変換

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistCa0 = []
q_ylistCa0 = []
a_xlistCa01 = []
q_xlistCa01 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_xを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistCa0.append(a_y)
 q_ylistCa0.append(q_y)
 a_xlistCa01.append(-9 * a_y / 43)#Be+のa_xに変換
 q_xlistCa01.append(-9 * q_y / 43)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistCa1 = []
q_ylistCa1 = []
a_xlistCa11 = []
q_xlistCa11 = []

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistCa1.append(a_y)
 q_ylistCa1.append(q_y)
 a_xlistCa11.append(-9 * a_y / 43)#Be+のa_xに変換
 q_xlistCa11.append(-9 * q_y / 43)#Be+のq_xに変換

 a_guess = a_y

 
#---Ca2+---

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistCa20 = []
q_xlistCa20 = []


a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistCa20.append(18 * a_x / 43)#Be+のa_xに変換
 q_xlistCa20.append(18 * q_x / 43)#Be+のq_xに変換

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistCa21 = []
q_xlistCa21 = []

a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistCa21.append(18 * a_x / 43)#Be+のa_xに変換
 q_xlistCa21.append(18 * q_x / 43)#Be+のq_xに変換

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistCa20 = []
q_ylistCa20 = []
a_xlistCa201 = []
q_xlistCa201 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistCa20.append(a_y)
 q_ylistCa20.append(q_y)
 a_xlistCa201.append(-18 * a_y / 43)#Be+のa_xに変換
 q_xlistCa201.append(-18 * q_y / 43)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistCa21 = []
q_ylistCa21 = []
a_xlistCa211 = []
q_xlistCa211 = []

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistCa21.append(a_y)
 q_ylistCa21.append(q_y)
 a_xlistCa211.append(-18 * a_y / 43)#Be+のa_xに変換
 q_xlistCa211.append(-18 * q_y / 43)#Be+のq_xに変換

 a_guess = a_y


plt.figure(figsize=(10,6))

#--Be+のグラフを描画--
plt.plot(q_xlistBe0, a_xlistBe0, color='red', label=r'$Be^+$', linewidth = 2, alpha = 0.7)#Be+  β_x下限
plt.plot(q_xlistBe1, a_xlistBe1, color='red', linewidth = 2)#Be+ β_x上限
plt.plot(q_xlistBe01, a_xlistBe01, color='red', linewidth = 2)#Be+　β_y下限
plt.plot(q_xlistBe11, a_xlistBe11, color='red', linewidth = 2)#Be+　β_y上限

#--Be2+のグラフを描画--
plt.plot(q_xlistBe2, a_xlistBe2, color='blue', label=r'$Be^{2+}$', linewidth = 2, alpha = 0.7)#Be2+　β_x下限
plt.plot(q_xlistBe21, a_xlistBe21, color='blue', linewidth = 2)#Be2+　β_x上限
plt.plot(q_xlistBe201, a_xlistBe201, color='blue', linewidth = 2)#Be2+ β_y下限
plt.plot(q_xlistBe211, a_xlistBe211, color='blue', linewidth = 2)#Be2+　β_y上限

#--He+のグラフを描画--
plt.plot(q_xlistHe0, a_xlistHe0, color='green', label=r'$He^+$', linewidth = 2, alpha = 0.7)#He+  β_x下限
plt.plot(q_xlistHe1, a_xlistHe1, color='green', linewidth = 2)#He+ β_x上限
plt.plot(q_xlistHe01, a_xlistHe01, color='green', linewidth = 2)#He+　β_y下限
plt.plot(q_xlistHe11, a_xlistHe11, color='green', linewidth = 2)#He+　β_y上限

#--He2+のグラフを描画--
plt.plot(q_xlistHe20, a_xlistHe20, color='orange', label=r'$He^{2+}$', linewidth = 2, alpha = 0.7)#Be2+　β_x下限
plt.plot(q_xlistHe21, a_xlistHe21, color='orange', linewidth = 2)#Be2+　β_x上限
plt.plot(q_xlistHe201, a_xlistHe201, color='orange', linewidth = 2)#Be2+ β_y下限
plt.plot(q_xlistHe211, a_xlistHe211, color='orange', linewidth = 2)#Be2+　β_y上限

#--Ce+のグラフを描画--
plt.plot(q_xlistCa0, a_xlistCa0, color='pink', label=r'$Ca^+$', linewidth = 2, alpha = 0.7)#Ca+  β_x下限
plt.plot(q_xlistCa1, a_xlistCa1, color='pink', linewidth = 2)#Ca+ β_x上限
plt.plot(q_xlistCa01, a_xlistCa01, color='pink', linewidth = 2)#Ca+　β_y下限
plt.plot(q_xlistCa11, a_xlistCa11, color='pink', linewidth = 2)#Ca+　β_y上限

#--Ca2+のグラフを描画--
plt.plot(q_xlistCa20, a_xlistCa20, color='purple', label=r'$Ca^{2+}$', linewidth = 2, alpha = 0.7)#Ca2+  β_x下限
plt.plot(q_xlistCa21, a_xlistCa21, color='purple', linewidth = 2)#Ca2+ β_x上限
plt.plot(q_xlistCa201, a_xlistCa201, color='purple', linewidth = 2)#Ca2+　β_y下限
plt.plot(q_xlistCa211, a_xlistCa211, color='purple', linewidth = 2)#Ca2+　β_y上限

plt.xlabel(r'$q_x$')
plt.ylabel(r'$a_x$')
plt.title('Stability diagram at D±4 in a linear trap')
plt.grid(True)
plt.xlim(0, 5)
plt.ylim(-2, 2)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

#--リニアトラップ(D±4までの近似)--
#--Be+とBe2+-- 

#--Be+--

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistBe0 = []
q_xlistBe0 = []

def f(a_x, q_x, beta_x):#関数を定義
    
     S_1 = (a_x - (2 + beta_x)**2)*(a_x - (4 + beta_x)**2) - q_x**2#D_4の分母
     S_2 = (a_x - (-2 + beta_x)**2)*(a_x - (-4 + beta_x)**2) - q_x**2#D_-4の分母
     S = (a_x - (4 + beta_x)**2)/ S_1 + (a_x - (-4 + beta_x)**2)/ S_2#連分数
     return  beta_x**2 - a_x + q_x**2 * S#方程式

a_guess = 0.0#初期値

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe0.append(a_x)
 q_xlistBe0.append(q_x)

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistBe1 = []
q_xlistBe1 = []

a_guess = 0.0#
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe1.append(a_x)
 q_xlistBe1.append(q_x)

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistBe0 = []
q_ylistBe0 = []
a_xlistBe01 = []
q_xlistBe01 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe0.append(a_y)
 q_ylistBe0.append(q_y)
 a_xlistBe01.append(-a_y)#a_xに変換
 q_xlistBe01.append(-q_y)#q_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistBe1 = []
q_ylistBe1 = []
a_xlistBe11 = []
q_xlistBe11 = []

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe1.append(a_y)
 q_ylistBe1.append(q_y)
 a_xlistBe11.append(-a_y)#a_xに変換
 q_xlistBe11.append(-q_y)#q_xに変換

 a_guess = a_y



#---Be2+---

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistBe2 = []
q_xlistBe2 = []


a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe2.append(2*a_x)#Be+のa_xに変換
 q_xlistBe2.append(2*q_x)#Be+のq_xに変換

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistBe21 = []
q_xlistBe21 = []

a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe21.append(2*a_x)#Be+のa_xに変換
 q_xlistBe21.append(2*q_x)#Be+のq_xに変換

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistBe2 = []
q_ylistBe2 = []
a_xlistBe201 = []
q_xlistBe201 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe2.append(a_y)
 q_ylistBe2.append(q_y)
 a_xlistBe201.append(-2*a_y)#Be+のa_xに変換
 q_xlistBe201.append(-2*q_y)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistBe21 = []
q_ylistBe21 = []
a_xlistBe211 = []
q_xlistBe211 = []

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe21.append(a_y)
 q_ylistBe21.append(q_y)
 a_xlistBe211.append(-2*a_y)#Be+のa_xに変換
 q_xlistBe211.append(-2*q_y)#Be+のq_xに変換

 a_guess = a_y



plt.figure(figsize=(10,6))

#--Be+のグラフを描画--
plt.plot(q_xlistBe0, a_xlistBe0, color='blue', label=r'$Be^+ (\beta_x = 0)$', linewidth = 2, alpha = 0.7)#Be+  β_x下限
plt.plot(q_xlistBe1, a_xlistBe1, color='red', label=r'$Be^+ (\beta_x = 1)$', linewidth = 2)#Be+ β_x上限
plt.plot(q_xlistBe01, a_xlistBe01, color='green', label=r'$Be^+ (\beta_y = 0)$', linewidth = 2)#Be+　β_y下限
plt.plot(q_xlistBe11, a_xlistBe11, color='orange', label=r'$Be^+ (\beta_y = 1)$', linewidth = 2)#Be+　β_y上限

#--Be2+のグラフを描画--
plt.plot(q_xlistBe2, a_xlistBe2, color='blue', linestyle = '-.', label=r'$Be^{2+} (\beta_x = 0)$', linewidth = 2, alpha = 0.7)#Be2+　β_x下限
plt.plot(q_xlistBe21, a_xlistBe21, color='red', linestyle = '-.', label=r'$Be^{2+} (\beta_x = 1)$', linewidth = 2)#Be2+　β_x上限
plt.plot(q_xlistBe201, a_xlistBe201, color='green', linestyle = '-.', label=r'$Be^{2+} (\beta_y = 0)$', linewidth = 2)#Be2+ β_y下限
plt.plot(q_xlistBe211, a_xlistBe211, color='orange', linestyle = '-.', label=r'$Be^{2+} (\beta_y = 1)$', linewidth = 2)#Be2+　β_y上限

plt.xlabel(r'$q_x$')
plt.ylabel(r'$a_x$')
plt.title('Stability diagram at D±4 in a linear trap')
plt.grid(True)
plt.xlim(0, 2)
plt.ylim(-0.75, 0.75)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

#--リニアトラップ(D±4までの近似)--
#--Be+とHe+--



#--Be+--

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistBe0 = []
q_xlistBe0 = []

def f(a_x, q_x, beta_x):#関数を定義
    
     S_1 = (a_x - (2 + beta_x)**2)*(a_x - (4 + beta_x)**2) - q_x**2#D_4の分母
     S_2 = (a_x - (-2 + beta_x)**2)*(a_x - (-4 + beta_x)**2) - q_x**2#D_-4の分母
     S = (a_x - (4 + beta_x)**2)/ S_1 + (a_x - (-4 + beta_x)**2)/ S_2#連分数
     return  beta_x**2 - a_x + q_x**2 * S#方程式

a_guess = 0.0#初期値

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe0.append(a_x)
 q_xlistBe0.append(q_x)

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistBe1 = []
q_xlistBe1 = []

a_guess = 0.0#初期値

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe1.append(a_x)
 q_xlistBe1.append(q_x)

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistBe0 = []
q_ylistBe0 = []
a_xlistBe01 = []
q_xlistBe01 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe0.append(a_y)
 q_ylistBe0.append(q_y)
 a_xlistBe01.append(-a_y)#Be+のa_xに変換
 q_xlistBe01.append(-q_y)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistBe1 = []
q_ylistBe1 = []
a_xlistBe11 = []
q_xlistBe11 = []

a_guess = 0.0#初期値

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe1.append(a_y)
 q_ylistBe1.append(q_y)
 a_xlistBe11.append(-a_y)#Be+のa_xに変換
 q_xlistBe11.append(-q_y)#Be+のq_xに変換

 a_guess = a_y


 #---He+---

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistHe0 = []
q_xlistHe0 = []


a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistHe0.append(9 * a_x / 4)#Be+のa_xに変換
 q_xlistHe0.append(9 * q_x / 4)#Be+のq_xに変換

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistHe1 = []
q_xlistHe1 = []

a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistHe1.append(9 * a_x / 4)#Be+のa_xに変換
 q_xlistHe1.append(9 * q_x / 4)#Be+のq_xに変換

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistHe0 = []
q_ylistHe0 = []
a_xlistHe01 = []
q_xlistHe01 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistHe0.append(a_y)
 q_ylistHe0.append(q_y)
 a_xlistHe01.append(-9 * a_y / 4)#Be+のa_xに変換
 q_xlistHe01.append(-9 * q_y / 4)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistHe1 = []
q_ylistHe1 = []
a_xlistHe11 = []
q_xlistHe11 = []

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistHe1.append(a_y)
 q_ylistHe1.append(q_y)
 a_xlistHe11.append(-9 * a_y / 4)#Be+のa_xに変換
 q_xlistHe11.append(-9 * q_y / 4)#Be+のq_xに変換

 a_guess = a_y

plt.figure(figsize=(10,6))

#--Be+のグラフを描画--
plt.plot(q_xlistBe0, a_xlistBe0, color='blue', label=r'$Be^+ (\beta_x = 0)$', linewidth = 2)#Be+ β_x下限
plt.plot(q_xlistBe1, a_xlistBe1, color='red', label=r'$Be^+ (\beta_x = 1)$', linewidth = 2)#Be+ β_x上限
plt.plot(q_xlistBe01, a_xlistBe01, color='green', label=r'$Be^+ (\beta_y = 0)$', linewidth = 2)#Be+ β_y下限
plt.plot(q_xlistBe11, a_xlistBe11, color='orange', label=r'$Be^+ (\beta_y = 1)$', linewidth = 2)#Be+ β_y上限

#--He+のグラフを描画--
plt.plot(q_xlistHe0, a_xlistHe0, color='blue', linestyle = '-.', label=r'$He^+ (\beta_x = 0)$', linewidth = 2)#He+  β_x下限
plt.plot(q_xlistHe1, a_xlistHe1, color='red', linestyle = '-.', label=r'$He^+ (\beta_x = 1)$', linewidth = 2)#He+ β_x上限
plt.plot(q_xlistHe01, a_xlistHe01, color='green', linestyle = '-.', label=r'$He^+ (\beta_y = 0)$', linewidth = 2)#He+　β_y下限
plt.plot(q_xlistHe11, a_xlistHe11, color='orange', linestyle = '-.', label=r'$He^+ (\beta_y = 1)$', linewidth = 2)#He+　β_y上限

plt.xlabel(r'$q_x$')
plt.ylabel(r'$a_x$')
plt.title('Stability diagram at D±4 in a linear trap')
plt.grid(True)
plt.xlim(0, 3)
plt.ylim(-0.8, 0.8)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

#--リニアトラップ(D±4までの近似)--
#--Be+とHe2+--


#--Be+--

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistBe0 = []
q_xlistBe0 = []

def f(a_x, q_x, beta_x):#関数を定義
    
     S_1 = (a_x - (2 + beta_x)**2)*(a_x - (4 + beta_x)**2) - q_x**2#D_4の分母
     S_2 = (a_x - (-2 + beta_x)**2)*(a_x - (-4 + beta_x)**2) - q_x**2#D_-4の分母
     S = (a_x - (4 + beta_x)**2)/ S_1 + (a_x - (-4 + beta_x)**2)/ S_2#連分数
     return  beta_x**2 - a_x + q_x**2 * S#方程式

a_guess = 0.0#初期値

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe0.append(a_x)
 q_xlistBe0.append(q_x)

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistBe1 = []
q_xlistBe1 = []

a_guess = 0.0#初期値

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe1.append(a_x)
 q_xlistBe1.append(q_x)

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistBe0 = []
q_ylistBe0 = []
a_xlistBe01 = []
q_xlistBe01 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値

for q_y in q:#q_xを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe0.append(a_y)
 q_ylistBe0.append(q_y)
 a_xlistBe01.append(-a_y)#Be+のa_xに変換
 q_xlistBe01.append(-q_y)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistBe1 = []
q_ylistBe1 = []
a_xlistBe11 = []
q_xlistBe11 = []

a_guess = 0.0#初期値

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe1.append(a_y)
 q_ylistBe1.append(q_y)
 a_xlistBe11.append(-a_y)#Be+のa_xに変換
 q_xlistBe11.append(-q_y)#Be+のq_xに変換

 a_guess = a_y


 #---He2+---

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistHe20 = []
q_xlistHe20 = []


a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistHe20.append(9 * a_x / 2)#Be+のa_xに変換
 q_xlistHe20.append(9 * q_x / 2)#Be+のq_xに変換

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistHe21 = []
q_xlistHe21 = []

a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistHe21.append(9 * a_x / 2)#Be+のa_xに変換
 q_xlistHe21.append(9 * q_x / 2)#Be+のq_xに変換

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistHe20 = []
q_ylistHe20 = []
a_xlistHe201 = []
q_xlistHe201 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistHe20.append(a_y)
 q_ylistHe20.append(q_y)
 a_xlistHe201.append(-9 * a_y / 2)#Be+のa_xに変換
 q_xlistHe201.append(-9 * q_y / 2)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistHe21 = []
q_ylistHe21 = []
a_xlistHe211 = []
q_xlistHe211 = []

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistHe21.append(a_y)
 q_ylistHe21.append(q_y)
 a_xlistHe211.append(-9 * a_y / 2)#Be+のa_xに変換
 q_xlistHe211.append(-9 * q_y / 2)#Be+のq_xに変換

 a_guess = a_y

plt.figure(figsize=(10,6))

#--Be+のグラフを描画--
plt.plot(q_xlistBe0, a_xlistBe0, color='blue', label=r'$Be^+ (\beta_x = 0)$', linewidth = 2)#Be+ β_x下限
plt.plot(q_xlistBe1, a_xlistBe1, color='red', label=r'$Be^+ (\beta_x = 1)$', linewidth = 2)#Be+ β_x上限
plt.plot(q_xlistBe01, a_xlistBe01, color='green', label=r'$Be^+ (\beta_y = 0)$', linewidth = 2)#Be+ β_y下限
plt.plot(q_xlistBe11, a_xlistBe11, color='orange', label=r'$Be^+ (\beta_y = 1)$', linewidth = 2)#Be+ β_y上限

#--He2+のグラフを描画--
plt.plot(q_xlistHe20, a_xlistHe20, color='blue', linestyle = ':', label=r'$He^{2+} (\beta_x = 0)$', linewidth = 2)#He2+　β_x下限
plt.plot(q_xlistHe21, a_xlistHe21, color='red', linestyle = ':', label=r'$He^{2+} (\beta_x = 1$)', linewidth = 2)#He2+　β_x上限
plt.plot(q_xlistHe201, a_xlistHe201, color='green', linestyle = ':', label=r'$He^{2+} (\beta_y = 0)$', linewidth = 2)#He2+ β_y下限
plt.plot(q_xlistHe211, a_xlistHe211, color='orange', linestyle = ':', label=r'$He^{2+} (\beta_y = 1)$', linewidth = 2)#He2+　β_y上限

plt.xlabel(r'$q_x$')
plt.ylabel(r'$a_x$')
plt.title('Stability diagram at D±4 in a linear trap')
plt.grid(True)
plt.xlim(0, 5)
plt.ylim(-2, 2)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

#--リニアトラップ(D±4までの近似)--
#--Be+とCa+--


#--Be+--

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistBe0 = []
q_xlistBe0 = []

def f(a_x, q_x, beta_x):#関数を定義
    
     S_1 = (a_x - (2 + beta_x)**2)*(a_x - (4 + beta_x)**2) - q_x**2#D_4の分母
     S_2 = (a_x - (-2 + beta_x)**2)*(a_x - (-4 + beta_x)**2) - q_x**2#D_-4の分母
     S = (a_x - (4 + beta_x)**2)/ S_1 + (a_x - (-4 + beta_x)**2)/ S_2#連分数
     return  beta_x**2 - a_x + q_x**2 * S#方程式

a_guess = 0.0#初期値

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe0.append(a_x)
 q_xlistBe0.append(q_x)

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistBe1 = []
q_xlistBe1 = []

a_guess = 0.0#初期値

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe1.append(a_x)
 q_xlistBe1.append(q_x)

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistBe0 = []
q_ylistBe0 = []
a_xlistBe01 = []
q_xlistBe01 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe0.append(a_y)
 q_ylistBe0.append(q_y)
 a_xlistBe01.append(-a_y)#Be+のa_xに変換
 q_xlistBe01.append(-q_y)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistBe1 = []
q_ylistBe1 = []
a_xlistBe11 = []
q_xlistBe11 = []

a_guess = 0.0#初期値

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe1.append(a_y)
 q_ylistBe1.append(q_y)
 a_xlistBe11.append(-a_y)#Be+のa_xに変換
 q_xlistBe11.append(-q_y)#Be+のq_xに変換

 a_guess = a_y


#---Ca+---

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistCa0 = []
q_xlistCa0 = []


a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistCa0.append(9 * a_x / 43)#Be+のa_xに変換
 q_xlistCa0.append(9 * q_x / 43)#Be+のq_xに変換

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistCa1 = []
q_xlistCa1 = []

a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistCa1.append(9 * a_x / 43)#Be+のa_xに変換
 q_xlistCa1.append(9 * q_x / 43)#Be+のq_xに変換

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistCa0 = []
q_ylistCa0 = []
a_xlistCa01 = []
q_xlistCa01 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistCa0.append(a_y)
 q_ylistCa0.append(q_y)
 a_xlistCa01.append(-9 * a_y / 43)#Be+のa_xに変換
 q_xlistCa01.append(-9 * q_y / 43)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistCa1 = []
q_ylistCa1 = []
a_xlistCa11 = []
q_xlistCa11 = []

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistCa1.append(a_y)
 q_ylistCa1.append(q_y)
 a_xlistCa11.append(-9 * a_y / 43)#Be+のa_xに変換
 q_xlistCa11.append(-9 * q_y / 43)#Be+のq_xに変換

 a_guess = a_y

plt.figure(figsize=(10,6))

#--Be+のグラフを描画--
plt.plot(q_xlistBe0, a_xlistBe0, color='blue', label=r'$Be^+ (\beta_x = 0)$', linewidth = 2)#Be+ β_x下限
plt.plot(q_xlistBe1, a_xlistBe1, color='red', label=r'$Be^+ (\beta_x = 1$)', linewidth = 2)#Be+ β_x上限
plt.plot(q_xlistBe01, a_xlistBe01, color='green', label=r'$Be^+ (\beta_y = 0)$', linewidth = 2)#Be+ β_y下限
plt.plot(q_xlistBe11, a_xlistBe11, color='orange', label=r'$Be^+ (\beta_y = 1)$', linewidth = 2)#Be+ β_y上限

#--Ce+のグラフを描画--
plt.plot(q_xlistCa0, a_xlistCa0, color='blue', linestyle = '-.', label=r'$Ca^+ (\beta_x = 0)$', linewidth = 2)#Ca+  β_x下限
plt.plot(q_xlistCa1, a_xlistCa1, color='red', linestyle = '-.', label=r'$Ca^+ (\beta_x = 1)$', linewidth = 2)#Ca+ β_x上限
plt.plot(q_xlistCa01, a_xlistCa01, color='green', linestyle = '-.', label=r'$Ca^+ (\beta_y = 0)$', linewidth = 2)#Ca+　β_y下限
plt.plot(q_xlistCa11, a_xlistCa11, color='orange', linestyle = '-.', label=r'$Ca^+ (\beta_y = 1)$', linewidth = 2)#Ca+　β_y上限

plt.xlabel(r'$q_x$')
plt.ylabel(r'$a_x$')
plt.title('Stability diagram at D±4 in a linear trap')
plt.grid(True)
plt.xlim(0, 1)
plt.ylim(-0.3, 0.3)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

#--リニアトラップ(D±4までの近似)--
#--Be+とCa2+--


#--Be+--

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistBe0 = []
q_xlistBe0 = []

def f(a_x, q_x, beta_x):#関数を定義
    
     S_1 = (a_x - (2 + beta_x)**2)*(a_x - (4 + beta_x)**2) - q_x**2#D_4の分母
     S_2 = (a_x - (-2 + beta_x)**2)*(a_x - (-4 + beta_x)**2) - q_x**2#D_-4の分母
     S = (a_x - (4 + beta_x)**2)/ S_1 + (a_x - (-4 + beta_x)**2)/ S_2#連分数
     return  beta_x**2 - a_x + q_x**2 * S#方程式

a_guess = 0.0#初期値

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe0.append(a_x)
 q_xlistBe0.append(q_x)

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistBe1 = []
q_xlistBe1 = []

a_guess = 0.0#初期値

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistBe1.append(a_x)
 q_xlistBe1.append(q_x)

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistBe0 = []
q_ylistBe0 = []
a_xlistBe01 = []
q_xlistBe01 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe0.append(a_y)
 q_ylistBe0.append(q_y)
 a_xlistBe01.append(-a_y)#Be+のa_xに変換
 q_xlistBe01.append(-q_y)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistBe1 = []
q_ylistBe1 = []
a_xlistBe11 = []
q_xlistBe11 = []

a_guess = 0.0#初期値

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistBe1.append(a_y)
 q_ylistBe1.append(q_y)
 a_xlistBe11.append(-a_y)#Be+のa_xに変換
 q_xlistBe11.append(-q_y)#Be+のq_xに変換

 a_guess = a_y


 #---Ca2+---

#--x軸方向の安定領域--


#--β_xの下限--

beta_x = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_xの範囲を定義
a_xlistCa20 = []
q_xlistCa20 = []


a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistCa20.append(18 * a_x / 43)#Be+のa_xに変換
 q_xlistCa20.append(18 * q_x / 43)#Be+のq_xに変換

 a_guess = a_x


#--β_xの上限--

beta_x = 1.0

a_xlistCa21 = []
q_xlistCa21 = []

a_guess = 0.0#初期値
a_x = 0#a_xをリセット

for q_x in q:#q_xを動かす

 ax_vals = fsolve(f, a_guess, args= (q_x, beta_x))#解を求める

 a_x = ax_vals[0]

 a_xlistCa21.append(18 * a_x / 43)#Be+のa_xに変換
 q_xlistCa21.append(18 * q_x / 43)#Be+のq_xに変換

 a_guess = a_x


#--y軸方向の安定領域--


#--β_yの下限--

beta_y = 0.0
q = np.linspace(-2.0, 2.0, 400)#q_yの範囲を定義
a_ylistCa20 = []
q_ylistCa20 = []
a_xlistCa201 = []
q_xlistCa201 = []

def f(a_y, q_y, beta_y):#関数を定義
    
     S_1 = (a_y - (2 + beta_y)**2)*(a_y - (4 + beta_y)**2) - q_y**2#D_4の分母
     S_2 = (a_y - (-2 + beta_y)**2)*(a_y - (-4 + beta_y)**2) - q_y**2#D_-4の分母
     S = (a_y - (4 + beta_y)**2)/ S_1 + (a_y - (-4 + beta_y)**2)/ S_2#連分数
     return  beta_y**2 - a_y + q_y**2 * S#方程式

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistCa20.append(a_y)
 q_ylistCa20.append(q_y)
 a_xlistCa201.append(-18 * a_y / 43)#Be+のa_xに変換
 q_xlistCa201.append(-18 * q_y / 43)#Be+のq_xに変換

 a_guess = a_y


#--β_yの上限--

beta_y = 1.0

a_ylistCa21 = []
q_ylistCa21 = []
a_xlistCa211 = []
q_xlistCa211 = []

a_guess = 0.0#初期値
a_y = 0#a_yをリセット

for q_y in q:#q_yを動かす

 ay_vals = fsolve(f, a_guess, args= (q_y, beta_y))#解を求める

 a_y = ay_vals[0]

 a_ylistCa21.append(a_y)
 q_ylistCa21.append(q_y)
 a_xlistCa211.append(-18 * a_y / 43)#Be+のa_xに変換
 q_xlistCa211.append(-18 * q_y / 43)#Be+のq_xに変換

 a_guess = a_y

plt.figure(figsize=(10,6))

#--Be+のグラフを描画--
plt.plot(q_xlistBe0, a_xlistBe0, color='blue', label=r'$Be^+ (\beta_x = 0)$', linewidth = 2)#Be+ β_x下限
plt.plot(q_xlistBe1, a_xlistBe1, color='red', label=r'$Be^+ (\beta_x = 1)$', linewidth = 2)#Be+ β_x上限
plt.plot(q_xlistBe01, a_xlistBe01, color='green', label=r'$Be^+ (\beta_y = 0)$', linewidth = 2)#Be+ β_y下限
plt.plot(q_xlistBe11, a_xlistBe11, color='orange', label=r'$Be^+ (\beta_y = 1)$', linewidth = 2)#Be+ β_y上限

#--Ca2+のグラフを描画--
plt.plot(q_xlistCa20, a_xlistCa20, color='blue', linestyle = '-.', label=r'$Ca^{2+} (\beta_x = 0)$', linewidth = 2)#Ca2+  β_x下限
plt.plot(q_xlistCa21, a_xlistCa21, color='red', linestyle = '-.', label=r'$Ca^{2+} (\beta_x = 1)$', linewidth = 2)#Ca2+ β_x上限
plt.plot(q_xlistCa201, a_xlistCa201, color='green', linestyle = '-.', label=r'$Ca^{2+} (\beta_y = 0)$', linewidth = 2)#Ca2+　β_y下限
plt.plot(q_xlistCa211, a_xlistCa211, color='orange', linestyle = '-.', label=r'$Ca^{2+} (\beta_y = 1)$', linewidth = 2)#Ca2+　β_y上限

plt.xlabel(r'$q_x$')
plt.ylabel(r'$a_x$')
plt.title('Stability diagram at D±4 in a linear trap')
plt.grid(True)
plt.xlim(0, 1)
plt.ylim(-0.3, 0.3)
plt.legend()
plt.show()
